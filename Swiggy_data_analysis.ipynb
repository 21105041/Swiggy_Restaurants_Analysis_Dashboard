# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Swiggy.csv")

# %%
data.head()
# Out:
#     ID         Area       City         Restaurant  Price  Avg ratings  \
# 0  211  Koramangala  Bangalore        Tandoor Hut    300          4.4
# 1  221  Koramangala  Bangalore      Tunday Kababi    300          4.1
# 2  246    Jogupalya  Bangalore            Kim Lee    650          4.4
# 3  248  Indiranagar  Bangalore  New Punjabi Hotel    250          3.9
# 4  249  Indiranagar  Bangalore                Nh8    350          4.0
#
#    Total ratings                                          Food type  \
# 0            100          Biryani,Chinese,North Indian,South Indian
# 1            100                                   Mughlai,Lucknowi
# 2            100                                            Chinese
# 3            500               North Indian,Punjabi,Tandoor,Chinese
# 4             50  Rajasthani,Gujarati,North Indian,Snacks,Desser...
#
#         Address  Delivery time
# 0     5Th Block             59
# 1     5Th Block             56
# 2   Double Road             50
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8680 entries, 0 to 8679
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ID             8680 non-null   int64
#  1   Area           8680 non-null   object
#  2   City           8680 non-null   object
#  3   Restaurant     8680 non-null   object
#  4   Price          8680 non-null   int64
#  5   Avg ratings    8680 non-null   float64
#  6   Total ratings  8680 non-null   int64
#  7   Food type      8680 non-null   object
#  8   Address        8680 non-null   object
#  9   Delivery time  8680 non-null   int64
# dtypes: float64(1), int64(4), object(5)
# memory usage: 678.3+ KB

# %%
data.describe()
# Out:
#                   ID        Price  Avg ratings  Total ratings  Delivery time
# count    8680.000000  8680.000000  8680.000000    8680.000000    8680.000000
# mean   244812.071429   348.444470     3.655104     156.634793      53.967051
# std    158671.617188   230.940074     0.647629     391.448014      14.292335
# min       211.000000     0.000000     2.000000      20.000000      20.000000
# 25%     72664.000000   200.000000     2.900000      50.000000      44.000000
# 50%    283442.000000   300.000000     3.900000      80.000000      53.000000
# 75%    393425.250000   400.000000     4.200000     100.000000      64.000000
# max    466928.000000  2500.000000     5.000000   10000.000000     109.000000

# %%
#rows and columns in dataset
data.shape
# Out:
# (8680, 10)

# %%
#chceking for null values
data.isnull().sum()
# Out:
# ID               0
# Area             0
# City             0
# Restaurant       0
# Price            0
# Avg ratings      0
# Total ratings    0
# Food type        0
# Address          0
# Delivery time    0
# dtype: int64

# %%
#checking for duplicate rows
data.duplicated().sum()
# Out:
# 0

# %%
#checking column names
data.columns.tolist()
# Out:
# ['ID',
#  'Area',
#  'City',
#  'Restaurant',
#  'Price',
#  'Avg ratings',
#  'Total ratings',
#  'Food type',
#  'Address',
#  'Delivery time']

# %%
data.head(20)
# Out:
#       ID                 Area       City  \
# 0    211          Koramangala  Bangalore
# 1    221          Koramangala  Bangalore
# 2    246            Jogupalya  Bangalore
# 3    248          Indiranagar  Bangalore
# 4    249          Indiranagar  Bangalore
# 5    254          Indiranagar  Bangalore
# 6    258          Indiranagar  Bangalore
# 7    263          Koramangala  Bangalore
# 8    267               Domlur  Bangalore
# 9    308          Koramangala  Bangalore
# 10   435          Koramangala  Bangalore
# 11   446           Cooke Town  Bangalore
# 12   453      Pulikeshi Nagar  Bangalore
# 13   464  Sivanchetti Gardens  Bangalore
# 14   504            Kodihalli  Bangalore
# 15   604          Koramangala  Bangalore
# 16   608               Domlur  Bangalore
# 17   621          Indiranagar  Bangalore
# 18  1050            Jayanagar  Bangalore
# 19  1299           Film Nagar  Hyderabad
#
#                                       Restaurant  Price  Avg ratings  \
# ...

# %%
#EXPLORATORY DATA ANALYSIS

data['ID'].nunique()
# Out:
# 8680

# %%
#unique cities in dataset
data['City'].unique()
# Out:
# array(['Bangalore', 'Hyderabad', 'Mumbai', 'Pune', 'Kolkata', 'Delhi',
#        'Chennai', 'Ahmedabad', 'Surat'], dtype=object)

# %%
data['Restaurant'].nunique()
# Out:
# 7865

# %%
data["Price"].max()
# Out:
# 2500

# %%
data["Price"].min()
# Out:
# 0

# %%
data.loc[data['Price'] == data['Price'].min()]
# Out:
#           ID            Area       City        Restaurant  Price  Avg ratings  \
# 1393   73662  Annanagar East    Chennai             Mozza      0          2.9
# 2830  283144           Athwa      Surat          Monginis      0          2.9
# 6995   55365         Isanpur  Ahmedabad  Maruti Dhosa Hub      0          4.1
# 6999   55710           Paldi  Ahmedabad   Ladli Fast Food      0          3.5
# 7218   77391        Ghodasar  Ahmedabad  Comfy Restaurant      0          4.0
#
#       Total ratings                            Food type        Address  \
# 1393             80  Continental,Chinese,Italian,Mexican  Annangar East
# 2830             80                             Desserts    Udhyognagar
# 6995             20                         South Indian   Vishal Nagar
# 6999             20                    Fast Food,Italian          Paldi
# 7218            100                       Indian,Chinese        Isanpur
#
#       Delivery time
# 1393             64
# 2830             46
# ...

# %%
#Removing rows with Price==0 
data = data[data['Price'] > 0]

# %%
# Check if any zero-price rows remain
print("Remaining zero-price rows:", (data['Price'] == 0).sum())
# Out:
# Remaining zero-price rows: 0

# %%
#checking for lowest values in Price column
data.sort_values(by = 'Price', ascending = True).head(20)
# Out:
#           ID                     Area       City  \
# 1054   48742                  Chembur     Mumbai
# 5871  443938                 Swargate       Pune
# 6371  463545              George Town    Chennai
# 6125  451785                  T Nagar    Chennai
# 8628  455469                 Ameerpet  Hyderabad
# 5030  408696                Charminar  Hyderabad
# 8659  460439              Navrangpura  Ahmedabad
# 8442  432980                Lake Town    Kolkata
# 5867  443862               Arumbakkam    Chennai
# 7500  128643                   Domlur  Bangalore
# 8529  445277                 Perambur    Chennai
# 1927  151192               Pitam Pura      Delhi
# 2128  180579               Ayanavaram    Chennai
# 5562  433263                  Alipore    Kolkata
# 2708  260557               Kurla West     Mumbai
# 6077  450524            Koregaon Park       Pune
# 8215  389482                Charminar  Hyderabad
# 8467  436423                 Perambur    Chennai
# ...

# %%
#removing the rows where Price is less than or equal to 5
data = data[data['Price'] > 5]

# %%
data.sort_values(by = 'Price', ascending = True).head(20)
# Out:
#           ID                     Area       City                 Restaurant  \
# 8442  432980                Lake Town    Kolkata            Grace Pav Bhaji
# 5867  443862               Arumbakkam    Chennai              Sri Sai Foods
# 7500  128643                   Domlur  Bangalore  Kota Kachori And Falahaar
# 1927  151192               Pitam Pura      Delhi                  Deem Seem
# 8529  445277                 Perambur    Chennai       Tea Time-Kodungaiyur
# 2128  180579               Ayanavaram    Chennai     Green Mango Juice Shop
# 5562  433263                  Alipore    Kolkata        Priya Tiffin Center
# 2708  260557               Kurla West     Mumbai         Deepak Farsan Mart
# 6077  450524            Koregaon Park       Pune                 Food Pride
# 8215  389482                Charminar  Hyderabad            Fancy Ice Cream
# 8467  436423                 Perambur    Chennai   Sanjana Foods And Snacks
# ...

# %%
data.to_excel("cleaned_swiggy_data.xlsx", index=False)
